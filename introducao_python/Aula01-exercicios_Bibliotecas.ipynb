# %% [markdown]
# # Introdução à linguagem Python para Ciência de Dados

# %% [markdown]
# ## Exercicios - Aula 1

# %% [markdown]
# ## 1 - Leia os dados da base Vehicle.csv e elimine as duas primeiras colunas.

# %%
import pandas as pd

data = pd.read_csv(r'C:\Users\saulosgil\OneDrive\Documentos\CursoMLeCD-USP\data\Vehicle.csv', encoding='ISO-8859-1')
data.head(5)
# Out:
#    Comp  Circ  D.Circ  Rad.Ra  Pr.Axis.Ra  Max.L.Ra  Scat.Ra  Elong  \
# 0    95    48      83     178          72        10      162     42
# 1    91    41      84     141          57         9      149     45
# 2   104    50     106     209          66        10      207     32
# 3    93    41      82     159          63         9      144     46
# 4    85    44      70     205         103        52      149     45
#
#    Pr.Axis.Rect  Max.L.Rect  Sc.Var.Maxis  Sc.Var.maxis  Ra.Gyr  Skew.Maxis  \
# 0            20         159           176           379     184          70
# 1            19         143           170           330     158          72
# 2            23         158           223           635     220          73
# 3            19         143           160           309     127          63
# 4            19         144           241           325     188         127
#
#    Skew.maxis  Kurt.maxis  Kurt.Maxis  Holl.Ra Class
# 0           6          16         187      197   van
# 1           9          14         189      199   van
# 2          14           9         188      196  saab
# 3           6          10         199      207   van
# 4           9          11         180      183   bus

# %%
# Removendo as 2 primeiras colunas do dataset  
data = data.iloc[:, 2:]
data.head(5)
# Out:
#    D.Circ  Rad.Ra  Pr.Axis.Ra  Max.L.Ra  Scat.Ra  Elong  Pr.Axis.Rect  \
# 0      83     178          72        10      162     42            20
# 1      84     141          57         9      149     45            19
# 2     106     209          66        10      207     32            23
# 3      82     159          63         9      144     46            19
# 4      70     205         103        52      149     45            19
#
#    Max.L.Rect  Sc.Var.Maxis  Sc.Var.maxis  Ra.Gyr  Skew.Maxis  Skew.maxis  \
# 0         159           176           379     184          70           6
# 1         143           170           330     158          72           9
# 2         158           223           635     220          73          14
# 3         143           160           309     127          63           6
# 4         144           241           325     188         127           9
#
#    Kurt.maxis  Kurt.Maxis  Holl.Ra Class
# 0          16         187      197   van
# 1          14         189      199   van
# 2           9         188      196  saab
# 3          10         199      207   van
# 4          11         180      183   bus

# %% [markdown]
# ## 2 - Mostre o histograma do quinto atributo.

# %%
import matplotlib.pyplot as plt

elong = data.iloc[:, 5] # seleciona o 5º atributo do dataset (Elong)

plt.figure(figsize=(10, 6))
plt.hist(elong, bins=30, color='blue', edgecolor='black')
plt.title('Histograma do Atributo Elong (5º Atributo do Dataset)')
plt.xlabel('Valores de Elong')
plt.ylabel('Frequência')    

plt.show()

# %% [markdown]
# ## 3 - Em um mesmo plot, mostre os gráficos da funções: $y = x^2 + 2$ e $y = 3*cos(x) + exp(x)$. Defina o intervalo [-10,10].

# %%
import numpy as np
import matplotlib.pyplot as plt

# intervalo
x  = np.linspace(-10, 10)

# funções
y1 = x**2 + 2
y2 = 3 * np.cos(x) + np.exp(x)

# plotando as funções
plt.figure(figsize=(10, 6))
plt.plot(x, y1, label='y = x² + 2', color='blue')
plt.plot(x, y2, label='y = 3*cos(x) + exp(x)', color='red')

# Configurações do gráfico
plt.title('Gráfico das funções')
plt.xlabel('x')
plt.ylabel('y')
plt.xlim(-10, 10)
plt.grid(True)
plt.legend()

# Exibir gráfico
plt.show()

# %% [markdown]
# ## 4 - Na curva 3D acima, troque a função seno pela cosseno.

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D  # necessario para habilitar projecoes 3D

fig = plt.figure(figsize=(10, 6))
    
# Cria um sistema de eixos com projecao 3D
ax = fig.add_subplot(111, projection='3d')

X = np.arange(-4, 4, 0.25)
Y = np.arange(-4, 4, 0.25)

# Cria a grade 2D de coordenadas (X, Y) para calcular Z em cada ponto
X, Y = np.meshgrid(X, Y)

# Calcula a distancia radial R e a altura Z = sin(R), gerando um padrao de ondas concentricas
R = np.sqrt(X ** 2 + Y ** 2)
Z = np.cos(R)

# plot_surface desenha a superficie 3D
# rstride/cstride controlam a resolucao da malha desenhada; cmap define o mapa de cores
ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap='hot')

plt.show()

# %% [markdown]
# ## 5 - Gere dois vetores de acordo com uma distribuição uniforme e mostre os resultados. Crie 100 observações de cada variável.

# %%
print(x1)
# Out:
# [ 7.53665068e-01 -7.42796249e-01 -3.45252108e-01 -1.73565084e-01
#   2.05257231e-01 -1.26216556e+00 -3.58809898e-01 -4.78815731e-01
#  -8.29640121e-01  7.54489194e-01 -1.89805116e+00 -1.74730511e+00
#   2.73425125e-01  1.43174461e+00 -4.79484407e-01  4.78419072e-01
#  -6.32961342e-01 -1.80676017e+00 -5.49203436e-01 -1.56789279e+00
#  -4.64401940e-01 -3.77704394e-02 -6.08232438e-01  3.10375424e-01
#  -4.54058943e-01 -3.74778974e-01  3.23367353e-01  1.33532769e+00
#  -1.00960709e-01  7.80909581e-01 -1.04124139e+00 -1.23408364e+00
#   1.10600061e-01  4.93408294e-01  8.43685305e-01  2.94974328e-01
#   1.94394778e-01  6.77893775e-01 -1.11043498e+00 -4.26933984e-02
#   7.05000497e-01  1.33004254e-01  6.53336219e-01  8.86318890e-01
#   6.11569343e-01  5.49915840e-01  3.72706304e-01  7.31018961e-01
#   5.23912437e-01 -5.24201328e-01  1.73122590e-01  5.89855275e-01
#   8.30134064e-02 -1.15095578e+00  1.33031113e-01  3.77378835e-02
#  -4.29461162e-02 -1.13181798e+00 -8.42036655e-01 -3.40443091e-01
#   3.16569669e-01  4.50591624e-01  6.72540182e-01 -4.48617094e-01
#   7.66575999e-04 -1.38198035e+00 -3.15059253e-01 -6.43400589e-01
#   3.60851820e-01 -7.52683124e-01  2.82392529e-01  5.65666666e-01
#  -5.87804456e-01 -2.14362368e-01 -3.43569162e-03 -2.88474403e-01
#   3.35123978e-01  8.80452417e-01  1.09125094e-01  1.17981575e+00
#  -2.71525839e-01  4.79941384e-01  3.30776807e-01  1.04540324e+00
#   7.61498476e-01  4.18019046e-01 -3.30616494e-03  4.89348388e-01
#   8.60987909e-01  8.13619768e-01 -2.07858911e-01  1.86736828e+00
#  -2.12930242e-02  1.11089497e-01 -4.85148776e-01 -7.81159147e-01
#   3.06359195e-01 -1.37239769e+00  8.06126572e-01 -2.24826489e-01]

# %%
import numpy as np
import matplotlib.pyplot as plt

# Gera tres amostras com distribuicoes normais diferentes (medias e desvios distintos)
x1 = np.random.normal(0, 0.8, 100)   # media=0, desvio=0.8
x2 = np.random.normal(-2, 1, 1000)    # media=-2, desvio=1

# Definimos um dicionario de argumentos comuns para reutilizar nos dois histogramas:
#   histtype='stepfilled' : desenha o histograma como uma area preenchida com contorno
#   alpha=0.5              : transparencia, para permitir ver a sobreposicao das distribuicoes
#   density=True           : normaliza o histograma para que a area total seja 1 (vira uma densidade)
#   bins=40                : numero de faixas
kwargs = dict(histtype='stepfilled', alpha=0.5, density=True, bins=60)

plt.figure(figsize=(10, 6))
plt.hist(x1, **kwargs, label='Média=0, Desvio=0.8')
plt.hist(x2, **kwargs, label='Média=-2, Desvio=1')

plt.legend()
plt.show()

# %% [markdown]
# Finalizado!
#
# Saulo Gil
#
# 😉
